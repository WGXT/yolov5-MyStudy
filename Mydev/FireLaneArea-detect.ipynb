# %%
# %pwd
# Out:
# 'e:\\CodeProject\\python\\yolov5-MyStudy\\Mydev'

# %%
# %cd ..
# Out:
# e:\CodeProject\python\yolov5-MyStudy

# %%
# %run train.py --data ./My-Train-Yaml/dataYaml/firelaneArea-detect.yaml --cfg ./My-Train-Yaml/modelYaml/firelaneArea_yolov5s.yaml --weights ./weights/yolov5s.pt --img 640 --epochs 200
# Out:
# train: weights=./weights/yolov5s.pt, cfg=./My-Train-Yaml/modelYaml/firelaneArea_yolov5s.yaml, data=./My-Train-Yaml/dataYaml/firelaneArea-detect.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  v7.0-167-g9e769bc Python-3.8.16 torch-1.13.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
#
# ...
